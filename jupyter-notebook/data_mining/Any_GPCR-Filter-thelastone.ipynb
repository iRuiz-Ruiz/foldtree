# %% [markdown]
# ### Functions

# %%
#load libraries
import pandas as pd
import numpy as np
import datetime
import os

# %%
# Extract unique categories from the brackets
def taxonomic_sorting(extension, database):
    categories = set()
    for entry in database['Taxonomic lineage']:
        if '(' in entry and ')' in entry:
            parts = [part.strip() for part in entry.split(',')]
            for part in parts:
                if '(' in part and ')' in part:
                    category = part.split('(')[-1].split(')')[0]
                    categories.add(category)

    # Create a dictionary to hold the data for each category
    category_data = {category: [] for category in categories}

    # Add the 'Org' column to the dictionary
    category_data['Org'] = list(database['Org'])

    # Iterate over each row and populate the dictionary
    for index, row in database.iterrows():
        for category in categories:
            category_data[category].append(next((entry.split('(')[0].strip() for entry in row['Taxonomic lineage'].split(', ') if category in entry), None))

    # Create a DataFrame from the dictionary
    df = pd.DataFrame(category_data)

    # Fill missing values with NaN
    df.fillna(value=np.nan, inplace=True)

    if extension == 'all':
        database = df[['Org','kingdom','clade1','clade2','phylum','subphylum','class','family']]
    elif extension == 'amoeba':
        if database.get('clade2') is not None:
            if database.get('class') is not None:
                database = df[['Org','clade1', 'phylum', 'class','clade2','family']]
            else:
                database = df[['Org','clade1', 'phylum','clade2','family']]
        else:
            database = df[['Org','clade1', 'phylum','family']]
    else:
        if database.get('kingdom') is not None:
            if database.get('phylum') is not None:
                database = df[['Org','kingdom','phylum','family']]
            else:
                database = df[['Org','kingdom','family']]
        else:
            database = df[['Org']]

    return database

def taxonomic_rename(extension, database):
    """
    Original names: 
    Bilateria (no rank), Deuterostomia (no rank), Vertebrata (no rank)
    Bilateria (no rank), Protostomia (no rank), Ecdysozoa (no rank)
    
    Bilateria (clade1), Deuterostomia (clade2), Vertebrata (Vertebrata)
    Bilateria (clade1), Protostomia (clade2), Ecdysozoa (Superphylum)

    """
    if macro == 'metazoa':
        if extension == 'all':
            #Taxonomic lineage rename
            database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), Opisthokonta (no rank), ",""))
            database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("Bilateria (no rank)","Bilateria (clade1)"))
        
            ##delimiting some ranks for vertebrata
            database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("Deuterostomia (no rank)","Deuterostomia (clade2)"))
            database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("Vertebrata (no rank)","Vertebrata (superphylum)"))
        
            ##delimiting some ranks for invertebrata
            database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("Protostomia (no rank)","Protostomia (clade2)"))
            database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("Ecdysozoa (no rank)","Ecdysozoa (superphylum)"))
        else:
             #Taxonomic lineage rename
            database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), Opisthokonta (no rank), ",""))
    
    elif macro == 'amoeba':
        #Taxonomic lineage rename
        database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
        database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("Amoebozoa (no rank)","Amoebozoa (clade1)"))
    
        ##delimiting ranks
        database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("Dictyostelia (no rank)","Dictyostelia (clade2)"))

    else:
        #Taxonomic lineage rename
        database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
    return database

def gene_summary(name, database, database_org):
    grouped = database.groupby(['Org', 'Gene']).count()

    database_pivoted = grouped.pivot_table(index='Org', columns='Gene', values='Entry', aggfunc='count')

    # Calculate row sums and column sums while ignoring NaN
    database_pivoted['Row_Sum'] = database_pivoted.sum(axis=1, skipna=True)
    database_pivoted.loc['Column_Sum'] = database_pivoted.sum(skipna=True)

    database_pivoted.reset_index(inplace=True)

    database_pivoted_merge = pd.merge(database_org, database_pivoted,  left_on='Org', right_on= 'Org', how='outer')

    database_summary = database_pivoted_merge[['Org', 'Row_Sum']]
    database_summary = database_summary[~(database_summary['Org'].str.contains('Column_Sum'))]
    database_name = name + '_gTotal'
    database_summary = database_summary.rename(columns={'Row_Sum': database_name})

    return database_pivoted_merge, database_summary

# %%
def get_organism(database):
    database_org = database[['Organism','Org']]
    database_org = database_org.drop_duplicates()
    return database_org

def get_lineage(extension,database):
    database_lng = database[['Org','Taxonomic lineage']]
    database_lng = database_lng.drop_duplicates()
    database_lng = taxonomic_sorting(extension,database_lng)
    return database_lng

def full_lineage(database_org, database_lng):
    database_org_lng = pd.merge(database_org, database_lng,  left_on='Org', right_on= 'Org', how='outer')
   # Reorder columns
    cols = database_org_lng.columns.tolist()
    cols = cols[2:] + cols[:2]  # Move the first two columns to the end
    database_org_lng = database_org_lng[cols]
    return database_org_lng

# %%
def process_dataset(name, type, extension, selected_data, gene_count):
    
    gpcr_org = get_organism(selected_data)
    gpcr_lng = get_lineage(extension, selected_data)
    gpcr_org_lng = full_lineage(gpcr_org, gpcr_lng)
    gpcr_genes, gpcr_summary = gene_summary(name,selected_data,gpcr_org)
    
    if gene_count == False:
        gpcr_genes = "Select gene_count = True to show the genes involved"

    taxonomy = gpcr_org_lng
    
    return gpcr_genes, gpcr_summary, taxonomy

# %%
def species_specific(item, species_list_custom, selected_data):
    species_room = []
    # loop to capture more than one specie
    new_specie = True
    for item in species_list_custom:
        # generate a specific entry list
        db_species = selected_data[selected_data['Organism'] == item]
        if db_species.empty:
            print('DataFrame is empty for ', item, '!')
        else:
            print('Entries found for ', item, '!')
            
        species_room.append(db_species)
    if species_room == []:
        species_dataframe = pd.DataFrame()
    else:
        species_dataframe = pd.concat(species_room)
        
    return species_dataframe

# %%
def uniprot_summary(gpcr, name, type, extension, nonredundant, gene_count, custom_organisms, alphafold, folder_name, tree_mapping):
    '''
    Will give error is datasets are empty. 
    '''
    if gpcr.empty == True:
        print("no info")
        gpcr_genes = "no info"
        gpcr_summary = "no info"
        gpcr_subset = "no info"
        taxonomy = "no info"
        tree_list = "no info"
        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
    else:  
        #drop empty values in AlphaFoldDB column 
        gpcr = gpcr.dropna(subset=['AlphaFoldDB'])
        gpcr = taxonomic_rename(extension, gpcr)
    
        gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
        
        #selecting data
        if type == 'reviewed':
            selected_data = gpcr[gpcr['Reviewed']=='reviewed']
            if selected_data.empty == True:
                return
            
        elif type == 'unreviewed':
            selected_data = gpcr[gpcr['Reviewed']=='unreviewed']
            if selected_data.empty == True:
                return
            
        elif type == 'all':
            selected_data = gpcr
            if selected_data.empty == True:
                return
        else:
            print("Please, input 'reviewed' or 'unreviewed'")
            
        #customize model 
        if custom_organisms == True:    
    
            #user_input = input("Uniprot organism to search (e.g. 'HUMAN', 'ORNAN'). 9CRUS and 9EUKA organisms need to specify a species:")
            user_input = 'HUMAN,DANRE,CHICK,ANOCA,XENLA,LATCH,CALMI,PETMA,BRAFL,CIOIN,SACKO,DROME,9CRUS,CAEEL,SCHMA,LIMPO,CAPTE,HELRO,STRPU,LOTGI,NEMVE,ACRDI,HYDVU,ANTEL,ACRMI,APLCA,TRIAD,MNELE,OSCCA,AMPQE,MONBE,SALR5,CAPO3,MINVI,9EUKA,CREFR,9EUKA,AMOPA,SCHPM,TUBME,NEUCS,YEAST,MICPC,CRYNE,COPCI,USTMD,9FUNG,MUCCI,RHIOR,ALLMA,ALLM3,BATDE,SPIPN,ENCCN,9MICR,THETB,DICDI,DICPU,HETPA,ENTHI,ACACA,ACACF,ARATH,ERYGU,AQUCA,BRADI,SORBI,SELML,PHYPA,CHLRE,CHLVA,OSTTA,MICPS,9FLOR,9RHOD,CYAME,CYAPA,ECTSI,NANGC,AURAN,PHATR,PHYIN,TOXGO,PLAFA,PARTE,TETTH,TETTS,PERM5,BIGNA,EMIHU,GUITH,NAEGR,TRIVA,GIAIN,TRYCR,LEIMA,PHATC,DIALT,CHRCT,PORPP,CHOCR,CYAM1,GALSU,NEOHI,PORUM'
            customised_flag = "customised"

            #species list custom - 9euka extended to haptophyta
            species_list_9euka = ['Sphaeroforma arctica','Abeoforma whisleri','Pirum gemmata','Corallochytrium limacisporum',
                                 'Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri)','Chrysochromulina tobinii',
                                  'Phaeocystis antarctica', #haptophyta
                                 'Calcidiscus leptoporus','Coccolithus braarudii','Haptolina brevifila','Haptolina ericina',
                                  'Emiliania huxleyi (Coccolithophore) (Pontosphaera huxleyi)',
                                 'Chrysotila carterae (Marine alga) (Syracosphaera carterae)','Prymnesium polylepis', 
                                 'Palpitomonas bilix'] # palpitomonas
            species_list_9crus = ['Daphnia magna']
            species_list_9fung = ['Podila verticillata NRRL 6337']
            species_list_9stra = ['Nannochloropsis gaditana']
            species_list_9alve = ['Perkinsus marinus']
            species_list_9micr = ['Nematocida parisii']
            #new added - rhodophyta
            species_list_9flor = ['Gracilariopsis chorda']
            species_list_9rhod = ['Compsopogon caeruleus','Rhodosorus marinus',
                                  'Timspurckia oligopyrenoides','Erythrolobus australicus']
            
            # Split the user input by comma and remove any extra whitespace
            items_org = user_input.split(',')
            items_org_else = user_input.split(',') #this is for the second list

            # Extract 9CRUS or 9EUKA 
            item1 = items_org.pop(items_org.index('9EUKA')) if '9EUKA' in items_org else None
            item2 = items_org.pop(items_org.index('9CRUS')) if '9CRUS' in items_org else None
            item3 = items_org.pop(items_org.index('9FUNG')) if '9FUNG' in items_org else None
            item4 = items_org.pop(items_org.index('9STRA')) if '9STRA' in items_org else None
            item5 = items_org.pop(items_org.index('9ALVE')) if '9ALVE' in items_org else None
            item6 = items_org.pop(items_org.index('9MICR')) if '9MICR' in items_org else None
            item7 = items_org.pop(items_org.index('9FLOR')) if '9FLOR' in items_org else None
            item8 = items_org.pop(items_org.index('9RHOD')) if '9RHOD' in items_org else None

            if items_org == []:
                if item1 == '9EUKA':
                    species_list_custom = species_list_9euka
                    
                    # calling function for picking the species specific
                    temp_dataset = species_specific(item1, species_list_custom, selected_data)

                    if temp_dataset.empty == True:
                        print("no info")
                        gpcr_genes = "no info"
                        gpcr_summary = "no info"
                        gpcr_subset = "no info"
                        taxonomy = "no info"
                        tree_list = "no info"
                        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
                    else:
                        selected_data = temp_dataset
                    
                elif item2 == '9CRUS':
                    species_list_custom = species_list_9crus
                    
                    temp_dataset = species_specific(item2,species_list_custom, selected_data)
                    if temp_dataset.empty == True:
                        print("no info")
                        gpcr_genes = "no info"
                        gpcr_summary = "no info"
                        gpcr_subset = "no info"
                        taxonomy = "no info"
                        tree_list = "no info"
                        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
                    else:
                        selected_data = temp_dataset
                    
                elif item3 == '9FUNG':
                    species_list_custom = species_list_9fung
                    
                    temp_dataset = species_specific(item3,species_list_custom, selected_data)
                    if temp_dataset.empty == True:
                        print("no info")
                        gpcr_genes = "no info"
                        gpcr_summary = "no info"
                        gpcr_subset = "no info"
                        taxonomy = "no info"
                        tree_list = "no info"
                        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
                        
                    else:
                        selected_data = temp_dataset
                    
                elif item4 == '9STRA':
                    species_list_custom = species_list_9stra
                    
                    temp_dataset = species_specific(item4,species_list_custom, selected_data)
                    
                    if temp_dataset.empty == True:
                        print("no info")
                        gpcr_genes = "no info"
                        gpcr_summary = "no info"
                        gpcr_subset = "no info"
                        taxonomy = "no info"
                        tree_list = "no info"
                        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
                        
                    else:
                        selected_data = temp_dataset
                    
                elif item5 == '9ALVE':
                    species_list_custom = species_list_9alve
                    
                    temp_dataset = species_specific(item5, species_list_custom, selected_data)
                    
                    if temp_dataset.empty == True:
                        print("no info")
                        gpcr_genes = "no info"
                        gpcr_summary = "no info"
                        gpcr_subset = "no info"
                        taxonomy = "no info"
                        tree_list = "no info"
                        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
                        
                    else:
                        selected_data = temp_dataset
                    
                elif item6 == '9MICR':
                    species_list_custom = species_list_9micr
                    
                    temp_dataset = species_specific(item6, species_list_custom, selected_data)
                    
                    if temp_dataset.empty == True:
                        print("no info")
                        gpcr_genes = "no info"
                        gpcr_summary = "no info"
                        gpcr_subset = "no info"
                        taxonomy = "no info"
                        tree_list = "no info"
                        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
                        
                    else:
                        selected_data = temp_dataset

                elif item7 == '9FLOR':
                    species_list_custom = species_list_9flor
                    
                    temp_dataset = species_specific(item7, species_list_custom, selected_data)
                    
                    if temp_dataset.empty == True:
                        print("no info")
                        gpcr_genes = "no info"
                        gpcr_summary = "no info"
                        gpcr_subset = "no info"
                        taxonomy = "no info"
                        tree_list = "no info"
                        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
                    else:
                        selected_data = temp_dataset

                elif item8 == '9RHOD':
                    species_list_custom = species_list_9rhod
                    
                    temp_dataset = species_specific(item8, species_list_custom, selected_data)
                    
                    if temp_dataset.empty == True:
                        print("no info")
                        gpcr_genes = "no info"
                        gpcr_summary = "no info"
                        gpcr_subset = "no info"
                        taxonomy = "no info"
                        tree_list = "no info"
                        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
                        
                    else:
                        selected_data = temp_dataset
                    
                else:
                    return 'No species has been included. Run this again'
                    
            # when the list is not empty, and there is more information 
            else:
                #general dataset to concat - avoided the 9CRUS, 9EUKA, ...
                gpcr_subset = selected_data[selected_data['Org'].str.contains('|'.join(items_org))]
                #selected_data_limited = gpcr_subset

                #the full dataset where we will extract the 9CRUS or 9EUKA
                gpcr_subset_full = selected_data[selected_data['Org'].str.contains('|'.join(items_org_else))]
                
                if item1 == '9EUKA':
                    species_list_custom = species_list_9euka
                    db_species1 = species_specific(item1, species_list_custom, gpcr_subset_full)
                else:
                    db_species1 = None
                    
                if item2 == '9CRUS':
                    species_list_custom = species_list_9crus
                    db_species2 = species_specific(item2, species_list_custom, gpcr_subset_full)
                else:
                    db_species2 = None

                if item3 == '9FUNG':
                    species_list_custom = species_list_9fung
                    db_species3 = species_specific(item3, species_list_custom, gpcr_subset_full)
                else:
                    db_species3 = None
                    
                if item4 == '9STRA':
                    species_list_custom = species_list_9stra
                    db_species4 = species_specific(item4, species_list_custom, gpcr_subset_full)
                else:
                    db_species4 = None
                    
                if item5 == '9ALVE':
                    species_list_custom = species_list_9alve
                    db_species5 = species_specific(item5, species_list_custom, gpcr_subset_full)
                else:
                    db_species5 = None
                    
                if item6 == '9MICR':
                    species_list_custom = species_list_9micr
                    db_species6 = species_specific(item6, species_list_custom, gpcr_subset_full)
                else: 
                    db_species6 = None

                if item7 == '9FLOR':
                    species_list_custom = species_list_9flor
                    db_species7 = species_specific(item7, species_list_custom, gpcr_subset_full)
                else: 
                    db_species7 = None

                if item8 == '9RHOD':
                    species_list_custom = species_list_9rhod
                    db_species8 = species_specific(item8, species_list_custom, gpcr_subset_full)
                else: 
                    db_species8 = None

            # List of tree DataFrame variables and their respective colors
            db_species_list = [db_species1, db_species2, db_species3, db_species4, db_species5, db_species6, db_species7, db_species8]
            valid_df = []
            # Loop through each tree, check if it is a valid DataFrame, then set color and add to list
            for db_spec in db_species_list:
                if isinstance(db_spec, pd.DataFrame):  # Check if the variable is a valid DataFrame
                    valid_df.append(db_spec)
                    
            # Concatenate the valid dataframes, if there is 
            df_species_specific_full = pd.concat(valid_df, ignore_index=True)
            print(df_species_specific_full)
            if df_species_specific_full.empty: 
                selected_data = gpcr_subset
                print('No species specific to include!')
            else:
                selected_data = pd.concat([gpcr_subset, df_species_specific_full])
                print('At least one species specific to include!')

            #save unique names per each organism (need for heatmap)
            selected_data['Scientific_Name'] = selected_data['Organism'].apply(lambda x: ' '.join(x.split()[:2]))
                
            if nonredundant == True:
                
                # Sort by 'Protein names', 'Org', and 'Length' in descending order
                gpcr_subset = selected_data.sort_values(by=['Protein names', 'Scientific_Name', 'Length'], ascending=[True, True, False])

                # Group by 'Protein names' and calculate the average length
                gpcr_avg_length = gpcr_subset.groupby('Protein names', as_index=False)['Length'].mean()

                ## rename column name 
                gpcr_avg_length = gpcr_avg_length.rename(columns={'Length': 'Average Length'})
                
                # merge the average length
                gpcr_subset = gpcr_subset.merge(gpcr_avg_length, on='Protein names')
                
                # How far is from the average - absolute value
                gpcr_subset['Length Distance'] = (gpcr_subset['Average Length'] - gpcr_subset['Length']).abs()
                
                # sort ascending
                gpcr_subset = gpcr_subset.sort_values(by=['Length Distance','Length'], ascending=[True,True])
                
                # Check individual protein names
                #pf01_subset_filtered[pf01_subset_filtered['Protein names'] == 'G-protein coupled receptor 55-like protein']
                
                # Drop duplicates, keeping the first occurrence (the closest to the average, and has the lower length)
                gpcr_subset = gpcr_subset.drop_duplicates(subset=['Protein names','Scientific_Name'])
                
                selected_data = gpcr_subset
                
            if selected_data.empty == True:
                print("no info")
                gpcr_genes = "no info"
                gpcr_summary = "no info"
                gpcr_subset = "no info"
                taxonomy = "no info"
                tree_list = "no info"
                return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list
            
        else:
            gpcr_subset = "Select 'True' for customised organisms, summary tables would reflect all the dataset"
            customised_flag = ""
            
        if alphafold == True:
    
            gpcr_list = selected_data['Entry']
            name_list = folder_name + '/' + name + '_' + type + '_' + customised_flag + '.txt'
            gpcr_list.to_csv(name_list, header=False, index=False)
    
        if tree_mapping == True:
    
            tree_list = selected_data[['Entry Name','Entry','Organism','Org','Scientific_Name','Gene','Protein names','Length']]
            tree_list['gpcr'] = name
    
        #this is one of the main function to summaryze the info
    
        gpcr_genes, gpcr_summary, taxonomy = process_dataset(name, type, extension, selected_data, gene_count)
    
        print('Summarizes:', name)
    
        return gpcr_genes, gpcr_summary, gpcr_subset, taxonomy, tree_list

# %% [markdown]
# ## working directory

# %%
os.chdir('/mnt/c/Users/ek23810/OneDrive - University of Bristol/term2_project/foldtree_tidy/outputs/mining/')  # Provide the new path here

# %%
out_dir = input('Set the output folder:')
out_dir = out_dir
# Out:
# Set the output folder: redo9-trash

# %% [markdown]
# ## Load databases - Any GPCR

# %%
gpcr_input = input('Uniprot GPCR identifier:')
taxa_input = input('Taxa to retrieve:')
# Out:
# Uniprot GPCR identifier: PF00001,PF00002,PF00003,PF01534,PF02076,PF02101,PF02116,PF02117,PF02118,PF02175,PF03006,PF03125,PF03383,PF03402,PF03619,PF04080,PF05296,PF05462,PF05875,PF06454,PF06814,PF10192,PF10292,PF10316,PF10317,PF10318,PF10319,PF10320,PF10321,PF10322,PF10323,PF10324,PF10325,PF10326,PF10327,PF10328,PF11710,PF11970,PF13853,PF13965,PF15100,PF12430
# Taxa to retrieve: 2759

# %%
gpcr_list = gpcr_input.split(',')
taxa_list = taxa_input.split(',')

# %%
#count the number of files 
c = 0
valid_trees = []
for taxa in taxa_list:
    for gpcr in gpcr_list:
        # file name
        PFAMID_taxa = gpcr + '-' + taxa
        print(PFAMID_taxa)
        file_download = '../../datasets/full/uniprot-' + PFAMID_taxa + '.tsv'
        
        # validation is a dataframe
        try:
            with open(file_download, 'r') as f:
                lines = f.readlines()
        except FileNotFoundError:
            c += 1
            print('FileNotFound')
            continue

        # continue, as the daframe contains data
        
        dataset = pd.read_csv(file_download, sep='\t')
        
        # parameters
        macro = ''
        
        type = 'all'
        extension = ''   
        gene_count = False
        # <------------------------------------------ select this one for custom organisms -------------------------------------------->
        custom_organisms = True
        # <------------------------------------------ select this one for custom organisms -------------------------------------------->
        nonredundant = False
        tree_mapping = True
        
        alphafold = True
         
        #generate a folder to store outputs
        alphafold_folder = out_dir + '/' + 'entries'
        # Specify the name of the new folder~
        folder_name = alphafold_folder + '/' + PFAMID_taxa + '_alphafold' + '_' + type + '_' + str(datetime.datetime.now())
        
        # Create the folder in the current working directory
        os.mkdir(folder_name)
    
        ## Any GPCR
        db_genes, db_summary, db_subset, db_taxonomy, db_tree = uniprot_summary(dataset, gpcr, type, extension, nonredundant, gene_count, 
                                                                           custom_organisms, alphafold, folder_name, tree_mapping)
        
        ## checking the tree
        if isinstance(db_tree, pd.DataFrame):  # Check if the variable is a valid DataFrame
            db_tree['gpcr'] = gpcr
            db_tree['taxa'] = taxa
            valid_trees.append(db_tree)
        
# Concatenate the valid DataFrames
if valid_trees == []:
    print('Nothing to generate. Entries is an empty folder')
else:
    tree_map_list = pd.concat(valid_trees, ignore_index=True)

    ## add pfam label
    label = pd.read_csv('../../pfam_labels.csv', sep=',')
    tree_map_list_labelled = pd.merge(tree_map_list, label,  left_on='gpcr', right_on= 'Accession', how='outer')

    ## add tree directory
    ## merge with taxonomy
    taxonomy_import = pd.read_csv('../../taxonomy_full_list_revised.csv')
    taxonomy_import = taxonomy_import.drop('Org', axis=1)
    
    tree_map_list_labelled = pd.merge(tree_map_list_labelled, taxonomy_import,  left_on='Scientific_Name', right_on= 'Scientific_Name', how='left')
    
    ## this merge was used for the file exported for the full dataset redo6 (17600 rows)
    tree_map_list_labelled['RL_Entry_Name'] = tree_map_list_labelled['Entry'] + '_' + tree_map_list_labelled['Org_Uq']

    tree_dir = out_dir + '/' + 'tree_metadata'
    comment = 'full'
    name_to_list =  tree_dir + '/' + 'compl' + comment + 'tree_map' + '_' + type + '.txt'
    tree_map_list_labelled.to_csv(name_to_list, header=True, index=False)
# Out:
# PF00001-2759
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# DataFrame is empty for  Sphaeroforma arctica !
# DataFrame is empty for  Abeoforma whisleri !
# DataFrame is empty for  Pirum gemmata !
# DataFrame is empty for  Corallochytrium limacisporum !
# Entries found for  Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri) !
# DataFrame is empty for  Chrysochromulina tobinii !
# DataFrame is empty for  Phaeocystis antarctica !
# DataFrame is empty for  Calcidiscus leptoporus !
# DataFrame is empty for  Coccolithus braarudii !
# Entries found for  Haptolina brevifila !
# DataFrame is empty for  Haptolina ericina !
# DataFrame is empty for  Emiliania huxleyi (Coccolithophore) (Pontosphaera huxleyi) !
# Entries found for  Chrysotila carterae (Marine alga) (Syracosphaera carterae) !
# DataFrame is empty for  Prymnesium polylepis !
# DataFrame is empty for  Palpitomonas bilix !
# Entries found for  Daphnia magna !
# DataFrame is empty for  Podila verticillata NRRL 6337 !
# DataFrame is empty for  Nematocida parisii !
# DataFrame is empty for  Gracilariopsis chorda !
# DataFrame is empty for  Compsopogon caeruleus !
# DataFrame is empty for  Rhodosorus marinus !
# DataFrame is empty for  Timspurckia oligopyrenoides !
# DataFrame is empty for  Erythrolobus australicus !
#           Entry    Reviewed        Entry Name  \
# 0    A0A7R9UU79  unreviewed  A0A7R9UU79_DIALT
# 1    A0A7S2JLX3  unreviewed  A0A7S2JLX3_9EUKA
# 2    A0A7S4BQ87  unreviewed  A0A7S4BQ87_CHRCT
# 3    A0A0N7ZJ72  unreviewed  A0A0N7ZJ72_9CRUS
# 4    A0A0N7ZK52  unreviewed  A0A0N7ZK52_9CRUS
# ..          ...         ...               ...
# 251  A0A164YWQ5  unreviewed  A0A164YWQ5_9CRUS
# 252  A0A164Z7G7  unreviewed  A0A164Z7G7_9CRUS
# 253  A0A164ZLS5  unreviewed  A0A164ZLS5_9CRUS
# 254  A0A164ZME7  unreviewed  A0A164ZME7_9CRUS
# 255  A0A165A8A5  unreviewed  A0A165A8A5_9CRUS
#
#                                          Protein names            Gene Names  \
# 0    G-protein coupled receptors family 1 profile d...   PLUT1463_LOCUS10507
# 1    G-protein coupled receptors family 1 profile d...   CBRE1094_LOCUS45494
# 2    G-protein coupled receptors family 1 profile d...  PCAR00345_LOCUS25897
# 3    Histamine H3 receptor (Pyroglutamylated RFamid...          APZ42_033509
# 4    Class a rhodopsin g-protein coupled receptor g...          APZ42_018929
# ..                                                 ...                   ...
# 251             RPE-retinal G protein-coupled receptor          APZ42_018898
# 252             Putative G-protein coupled receptor 45          APZ42_018285
# 253        Bombesin receptor subtype-3/sw-like protein          APZ42_017741
# 254            Putative G-protein coupled receptor 161          APZ42_017742
# 255  G-protein coupled receptors family 1 profile d...          APZ42_016929
#
#                                               Organism  Length  AlphaFoldDB  \
# 0    Diacronema lutheri (Unicellular marine alga) (...     273  A0A7R9UU79;
# 1                                  Haptolina brevifila     321  A0A7S2JLX3;
# 2    Chrysotila carterae (Marine alga) (Syracosphae...     511  A0A7S4BQ87;
# 3                                        Daphnia magna     514  A0A0N7ZJ72;
# 4                                        Daphnia magna     617  A0A0N7ZK52;
# ..                                                 ...     ...          ...
# 251                                      Daphnia magna     359  A0A164YWQ5;
# 252                                      Daphnia magna     944  A0A164Z7G7;
# 253                                      Daphnia magna     760  A0A164ZLS5;
# 254                                      Daphnia magna     651  A0A164ZME7;
# 255                                      Daphnia magna     368  A0A165A8A5;
#
#                                      Taxonomic lineage  Organism (ID)  \
# 0    Haptista (clade), Haptophyta (phylum), Pavlova...        2081491
# 1    Haptista (clade), Haptophyta (phylum), Prymnes...         156173
# 2    Haptista (clade), Haptophyta (phylum), Prymnes...          13221
# 3    Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 4    Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# ..                                                 ...            ...
# 251  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 252  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 253  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 254  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 255  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
#
#            Gene    Org
# 0    A0A7R9UU79  DIALT
# 1    A0A7S2JLX3  9EUKA
# 2    A0A7S4BQ87  CHRCT
# 3    A0A0N7ZJ72  9CRUS
# 4    A0A0N7ZK52  9CRUS
# ..          ...    ...
# 251  A0A164YWQ5  9CRUS
# 252  A0A164Z7G7  9CRUS
# 253  A0A164ZLS5  9CRUS
# 254  A0A164ZME7  9CRUS
# 255  A0A165A8A5  9CRUS
#
# [256 rows x 12 columns]
# At least one species specific to include!
# Summarizes: PF00001
# PF00002-2759
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# DataFrame is empty for  Sphaeroforma arctica !
# DataFrame is empty for  Abeoforma whisleri !
# DataFrame is empty for  Pirum gemmata !
# DataFrame is empty for  Corallochytrium limacisporum !
# DataFrame is empty for  Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri) !
# DataFrame is empty for  Chrysochromulina tobinii !
# DataFrame is empty for  Phaeocystis antarctica !
# DataFrame is empty for  Calcidiscus leptoporus !
# DataFrame is empty for  Coccolithus braarudii !
# DataFrame is empty for  Haptolina brevifila !
# DataFrame is empty for  Haptolina ericina !
# DataFrame is empty for  Emiliania huxleyi (Coccolithophore) (Pontosphaera huxleyi) !
# DataFrame is empty for  Chrysotila carterae (Marine alga) (Syracosphaera carterae) !
# DataFrame is empty for  Prymnesium polylepis !
# DataFrame is empty for  Palpitomonas bilix !
# Entries found for  Daphnia magna !
# DataFrame is empty for  Podila verticillata NRRL 6337 !
# DataFrame is empty for  Nematocida parisii !
# DataFrame is empty for  Gracilariopsis chorda !
# Entries found for  Compsopogon caeruleus !
# DataFrame is empty for  Rhodosorus marinus !
# DataFrame is empty for  Timspurckia oligopyrenoides !
# DataFrame is empty for  Erythrolobus australicus !
#          Entry    Reviewed        Entry Name  \
# 0   A0A0N8AV83  unreviewed  A0A0N8AV83_9CRUS
# 1   A0A0N8CKR5  unreviewed  A0A0N8CKR5_9CRUS
# 2   A0A0P5ACH2  unreviewed  A0A0P5ACH2_9CRUS
# 3   A0A0P5D8X9  unreviewed  A0A0P5D8X9_9CRUS
# 4   A0A0P5GQ59  unreviewed  A0A0P5GQ59_9CRUS
# 5   A0A0P5I7B3  unreviewed  A0A0P5I7B3_9CRUS
# 6   A0A0P5IYH2  unreviewed  A0A0P5IYH2_9CRUS
# 7   A0A0P5J372  unreviewed  A0A0P5J372_9CRUS
# 8   A0A0P5K667  unreviewed  A0A0P5K667_9CRUS
# 9   A0A0P5RSB9  unreviewed  A0A0P5RSB9_9CRUS
# 10  A0A0P5USD4  unreviewed  A0A0P5USD4_9CRUS
# 11  A0A0P6DK95  unreviewed  A0A0P6DK95_9CRUS
# 12  A0A0P6DKP3  unreviewed  A0A0P6DKP3_9CRUS
# 13  A0A0P6G4C1  unreviewed  A0A0P6G4C1_9CRUS
# 14  A0A0P6IPF1  unreviewed  A0A0P6IPF1_9CRUS
# 15  A0A162PLB8  unreviewed  A0A162PLB8_9CRUS
# 16  A0A162R3I2  unreviewed  A0A162R3I2_9CRUS
# 17  A0A162R4Q4  unreviewed  A0A162R4Q4_9CRUS
# 18  A0A162SAB1  unreviewed  A0A162SAB1_9CRUS
# 19  A0A164LLU6  unreviewed  A0A164LLU6_9CRUS
# 20  A0A164PP62  unreviewed  A0A164PP62_9CRUS
# 21  A0A164XLH6  unreviewed  A0A164XLH6_9CRUS
# 22  A0A165A4C4  unreviewed  A0A165A4C4_9CRUS
# 23  A0A0N8CWA7  unreviewed  A0A0N8CWA7_9CRUS
# 24  A0A0P4YZX8  unreviewed  A0A0P4YZX8_9CRUS
# 25  A0A0P4Z544  unreviewed  A0A0P4Z544_9CRUS
# 26  A0A0P5CAW6  unreviewed  A0A0P5CAW6_9CRUS
# 27  A0A0P5N1G0  unreviewed  A0A0P5N1G0_9CRUS
# 28  A0A0P5TK30  unreviewed  A0A0P5TK30_9CRUS
# 29  A0A0P5TPY8  unreviewed  A0A0P5TPY8_9CRUS
# 30  A0A0P5WKU3  unreviewed  A0A0P5WKU3_9CRUS
# 31  A0A0P6C0F3  unreviewed  A0A0P6C0F3_9CRUS
# 32  A0A0P6EKE5  unreviewed  A0A0P6EKE5_9CRUS
# 33  A0A162CGB3  unreviewed  A0A162CGB3_9CRUS
# 34  A0A164NG33  unreviewed  A0A164NG33_9CRUS
# 35  A0A164RH07  unreviewed  A0A164RH07_9CRUS
# 36  A0A7S1TA08  unreviewed  A0A7S1TA08_9RHOD
# 37  A0A7S1TCI4  unreviewed  A0A7S1TCI4_9RHOD
#
#                                         Protein names          Gene Names  \
# 0             Corticotropin-releasing factor receptor                 NaN
# 1   Class b secretin g-protein coupled receptor gp...        APZ42_010954
# 2             Corticotropin-releasing factor receptor                 NaN
# 3             Corticotropin-releasing factor receptor                 NaN
# 4             Corticotropin-releasing factor receptor                 NaN
# 5             Corticotropin-releasing factor receptor                 NaN
# 6                      G-protein coupled receptor Mth                 NaN
# 7                      G-protein coupled receptor Mth                 NaN
# 8                      G-protein coupled receptor Mth                 NaN
# 9             Corticotropin-releasing factor receptor                 NaN
# 10  Corticotropin-releasing factor receptor (Diure...        APZ42_013185
# 11            Corticotropin-releasing factor receptor                 NaN
# 12            Corticotropin-releasing factor receptor                 NaN
# 13            Corticotropin-releasing factor receptor                 NaN
# 14            Corticotropin-releasing factor receptor                 NaN
# 15  G-protein coupled receptors family 2 profile 2...        APZ42_014776
# 16                         Methuselah 15-like protein        APZ42_013187
# 17              Putative Diuretic hormone 44 receptor        APZ42_013223
# 18    Putative Adhesion G protein-coupled receptor B3        APZ42_012018
# 19                    G-protein-coupled receptor Mth2        APZ42_032508
# 20    Calcitonin gene-related peptide type 1 receptor        APZ42_029572
# 21                             Putative DH31 receptor        APZ42_020325
# 22  G-protein coupled receptors family 2 profile 2...        APZ42_016761
# 23  Class b secretin g-protein coupled receptor gp...                 NaN
# 24  Class b secretin g-protein coupled receptor gp...                 NaN
# 25  Class b secretin g-protein coupled receptor gp...                 NaN
# 26  Class b secretin g-protein coupled receptor gp...                 NaN
# 27  Class b secretin g-protein coupled receptor gp...                 NaN
# 28  Class b secretin g-protein coupled receptor gp...                 NaN
# 29  Class b secretin g-protein coupled receptor gp...        APZ42_017273
# 30  G-protein coupled receptor Mth (Methuselah 15-...        APZ42_017202
# 31  Class b secretin g-protein coupled receptor gp...        APZ42_013410
# 32  Class B secretin G-protein coupled receptor GP...                 NaN
# 33        Putative G-protein coupled receptor, orphan        APZ42_018707
# 34          Putative G-protein coupled receptor Mth 6        APZ42_030892
# 35             Adhesion G protein-coupled receptor L4        APZ42_027297
# 36  G-protein coupled receptors family 2 profile 2...  CCAE0312_LOCUS2445
# 37  G-protein coupled receptors family 2 profile 2...  CCAE0312_LOCUS2444
#
#                  Organism  Length  AlphaFoldDB  \
# 0           Daphnia magna     534  A0A0N8AV83;
# 1           Daphnia magna     884  A0A0N8CKR5;
# 2           Daphnia magna     557  A0A0P5ACH2;
# 3           Daphnia magna     535  A0A0P5D8X9;
# 4           Daphnia magna     557  A0A0P5GQ59;
# 5           Daphnia magna     435  A0A0P5I7B3;
# 6           Daphnia magna     641  A0A0P5IYH2;
# 7           Daphnia magna     699  A0A0P5J372;
# 8           Daphnia magna     641  A0A0P5K667;
# 9           Daphnia magna     534  A0A0P5RSB9;
# 10          Daphnia magna     534  A0A0P5USD4;
# 11          Daphnia magna     639  A0A0P6DK95;
# 12          Daphnia magna     639  A0A0P6DKP3;
# 13          Daphnia magna     662  A0A0P6G4C1;
# 14          Daphnia magna     662  A0A0P6IPF1;
# 15          Daphnia magna     848  A0A162PLB8;
# 16          Daphnia magna     861  A0A162R3I2;
# 17          Daphnia magna     374  A0A162R4Q4;
# 18          Daphnia magna    1089  A0A162SAB1;
# 19          Daphnia magna     699  A0A164LLU6;
# 20          Daphnia magna     718  A0A164PP62;
# 21          Daphnia magna     481  A0A164XLH6;
# 22          Daphnia magna     866  A0A165A4C4;
# 23          Daphnia magna     766  A0A0N8CWA7;
# 24          Daphnia magna     770  A0A0P4YZX8;
# 25          Daphnia magna     770  A0A0P4Z544;
# 26          Daphnia magna     770  A0A0P5CAW6;
# 27          Daphnia magna    1052  A0A0P5N1G0;
# 28          Daphnia magna     770  A0A0P5TK30;
# 29          Daphnia magna     699  A0A0P5TPY8;
# 30          Daphnia magna     574  A0A0P5WKU3;
# 31          Daphnia magna     521  A0A0P6C0F3;
# 32          Daphnia magna     588  A0A0P6EKE5;
# 33          Daphnia magna     555  A0A162CGB3;
# 34          Daphnia magna     656  A0A164NG33;
# 35          Daphnia magna    1038  A0A164RH07;
# 36  Compsopogon caeruleus     330  A0A7S1TA08;
# 37  Compsopogon caeruleus     253  A0A7S1TCI4;
#
#                                     Taxonomic lineage  Organism (ID)  \
# 0   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 1   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 2   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 3   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 4   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 5   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 6   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 7   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 8   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 9   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 10  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 11  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 12  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 13  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 14  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 15  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 16  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 17  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 18  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 19  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 20  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 21  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 22  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 23  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 24  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 25  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 26  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 27  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 28  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 29  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 30  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 31  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 32  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 33  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 34  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 35  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 36  Rhodophyta (phylum), Compsopogonophyceae (clas...          31354
# 37  Rhodophyta (phylum), Compsopogonophyceae (clas...          31354
#
#           Gene    Org
# 0   A0A0N8AV83  9CRUS
# 1   A0A0N8CKR5  9CRUS
# 2   A0A0P5ACH2  9CRUS
# 3   A0A0P5D8X9  9CRUS
# 4   A0A0P5GQ59  9CRUS
# 5   A0A0P5I7B3  9CRUS
# 6   A0A0P5IYH2  9CRUS
# 7   A0A0P5J372  9CRUS
# 8   A0A0P5K667  9CRUS
# 9   A0A0P5RSB9  9CRUS
# 10  A0A0P5USD4  9CRUS
# 11  A0A0P6DK95  9CRUS
# 12  A0A0P6DKP3  9CRUS
# 13  A0A0P6G4C1  9CRUS
# 14  A0A0P6IPF1  9CRUS
# 15  A0A162PLB8  9CRUS
# 16  A0A162R3I2  9CRUS
# 17  A0A162R4Q4  9CRUS
# 18  A0A162SAB1  9CRUS
# 19  A0A164LLU6  9CRUS
# 20  A0A164PP62  9CRUS
# 21  A0A164XLH6  9CRUS
# 22  A0A165A4C4  9CRUS
# 23  A0A0N8CWA7  9CRUS
# 24  A0A0P4YZX8  9CRUS
# 25  A0A0P4Z544  9CRUS
# 26  A0A0P5CAW6  9CRUS
# 27  A0A0P5N1G0  9CRUS
# 28  A0A0P5TK30  9CRUS
# 29  A0A0P5TPY8  9CRUS
# 30  A0A0P5WKU3  9CRUS
# 31  A0A0P6C0F3  9CRUS
# 32  A0A0P6EKE5  9CRUS
# 33  A0A162CGB3  9CRUS
# 34  A0A164NG33  9CRUS
# 35  A0A164RH07  9CRUS
# 36  A0A7S1TA08  9RHOD
# 37  A0A7S1TCI4  9RHOD
# At least one species specific to include!
# Summarizes: PF00002
# PF00003-2759
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# DataFrame is empty for  Sphaeroforma arctica !
# DataFrame is empty for  Abeoforma whisleri !
# DataFrame is empty for  Pirum gemmata !
# DataFrame is empty for  Corallochytrium limacisporum !
# DataFrame is empty for  Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri) !
# DataFrame is empty for  Chrysochromulina tobinii !
# Entries found for  Phaeocystis antarctica !
# Entries found for  Calcidiscus leptoporus !
# DataFrame is empty for  Coccolithus braarudii !
# Entries found for  Haptolina brevifila !
# DataFrame is empty for  Haptolina ericina !
# Entries found for  Emiliania huxleyi (Coccolithophore) (Pontosphaera huxleyi) !
# Entries found for  Chrysotila carterae (Marine alga) (Syracosphaera carterae) !
# Entries found for  Prymnesium polylepis !
# DataFrame is empty for  Palpitomonas bilix !
# Entries found for  Daphnia magna !
# DataFrame is empty for  Podila verticillata NRRL 6337 !
# DataFrame is empty for  Nematocida parisii !
# DataFrame is empty for  Gracilariopsis chorda !
# DataFrame is empty for  Compsopogon caeruleus !
# DataFrame is empty for  Rhodosorus marinus !
# DataFrame is empty for  Timspurckia oligopyrenoides !
# DataFrame is empty for  Erythrolobus australicus !
#          Entry    Reviewed        Entry Name  \
# 0   A0A7S0ELE1  unreviewed  A0A7S0ELE1_9EUKA
# 1   A0A7S0HS19  unreviewed  A0A7S0HS19_9EUKA
# 2   A0A7S0E8J8  unreviewed  A0A7S0E8J8_9EUKA
# 3   A0A7S0HPX1  unreviewed  A0A7S0HPX1_9EUKA
# 4   A0A7S0JLD6  unreviewed  A0A7S0JLD6_9EUKA
# ..         ...         ...               ...
# 94  A0A164KUD4  unreviewed  A0A164KUD4_9CRUS
# 95  A0A164L885  unreviewed  A0A164L885_9CRUS
# 96  A0A164NJ73  unreviewed  A0A164NJ73_9CRUS
# 97  A0A164UIV2  unreviewed  A0A164UIV2_9CRUS
# 98  A0A164UIZ4  unreviewed  A0A164UIZ4_9CRUS
#
#                                         Protein names           Gene Names  \
# 0   G-protein coupled receptors family 3 profile d...  PANT1444_LOCUS10313
# 1   G-protein coupled receptors family 3 profile d...  PANT1444_LOCUS12556
# 2   G-protein coupled receptors family 3 profile d...   PANT1444_LOCUS5374
# 3   G-protein coupled receptors family 3 profile d...  PANT1444_LOCUS12664
# 4   G-protein coupled receptors family 3 profile d...  CLEP1334_LOCUS30104
# ..                                                ...                  ...
# 94                     Taste receptor type 1 member 2         APZ42_033733
# 95                         G-protein-coupled receptor         APZ42_033295
# 96                         Putative Poor gastrulation         APZ42_030481
# 97                     Taste receptor type 1 member 2         APZ42_024155
# 98                    Metabotropic glutamate receptor         APZ42_024206
#
#                   Organism  Length  AlphaFoldDB  \
# 0   Phaeocystis antarctica     523  A0A7S0ELE1;
# 1   Phaeocystis antarctica     503  A0A7S0HS19;
# 2   Phaeocystis antarctica     116  A0A7S0E8J8;
# 3   Phaeocystis antarctica     824  A0A7S0HPX1;
# 4   Calcidiscus leptoporus     111  A0A7S0JLD6;
# ..                     ...     ...          ...
# 94           Daphnia magna    1007  A0A164KUD4;
# 95           Daphnia magna     551  A0A164L885;
# 96           Daphnia magna     716  A0A164NJ73;
# 97           Daphnia magna     403  A0A164UIV2;
# 98           Daphnia magna     868  A0A164UIZ4;
#
#                                     Taxonomic lineage  Organism (ID)  \
# 0   Haptista (clade), Haptophyta (phylum), Prymnes...          33657
# 1   Haptista (clade), Haptophyta (phylum), Prymnes...          33657
# 2   Haptista (clade), Haptophyta (phylum), Prymnes...          33657
# 3   Haptista (clade), Haptophyta (phylum), Prymnes...          33657
# 4   Haptista (clade), Haptophyta (phylum), Prymnes...         127549
# ..                                                ...            ...
# 94  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 95  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 96  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 97  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 98  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
#
#           Gene    Org
# 0   A0A7S0ELE1  9EUKA
# 1   A0A7S0HS19  9EUKA
# 2   A0A7S0E8J8  9EUKA
# 3   A0A7S0HPX1  9EUKA
# 4   A0A7S0JLD6  9EUKA
# ..         ...    ...
# 94  A0A164KUD4  9CRUS
# 95  A0A164L885  9CRUS
# 96  A0A164NJ73  9CRUS
# 97  A0A164UIV2  9CRUS
# 98  A0A164UIZ4  9CRUS
#
# [99 rows x 12 columns]
# At least one species specific to include!
# Summarizes: PF00003
# PF01534-2759
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# DataFrame is empty for  Sphaeroforma arctica !
# DataFrame is empty for  Abeoforma whisleri !
# DataFrame is empty for  Pirum gemmata !
# DataFrame is empty for  Corallochytrium limacisporum !
# DataFrame is empty for  Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri) !
# DataFrame is empty for  Chrysochromulina tobinii !
# Entries found for  Phaeocystis antarctica !
# DataFrame is empty for  Calcidiscus leptoporus !
# DataFrame is empty for  Coccolithus braarudii !
# DataFrame is empty for  Haptolina brevifila !
# DataFrame is empty for  Haptolina ericina !
# DataFrame is empty for  Emiliania huxleyi (Coccolithophore) (Pontosphaera huxleyi) !
# Entries found for  Chrysotila carterae (Marine alga) (Syracosphaera carterae) !
# DataFrame is empty for  Prymnesium polylepis !
# DataFrame is empty for  Palpitomonas bilix !
# Entries found for  Daphnia magna !
# DataFrame is empty for  Podila verticillata NRRL 6337 !
# DataFrame is empty for  Nematocida parisii !
# DataFrame is empty for  Gracilariopsis chorda !
# DataFrame is empty for  Compsopogon caeruleus !
# DataFrame is empty for  Rhodosorus marinus !
# DataFrame is empty for  Timspurckia oligopyrenoides !
# DataFrame is empty for  Erythrolobus australicus !
#         Entry    Reviewed        Entry Name  \
# 0  A0A7S0HIM9  unreviewed  A0A7S0HIM9_9EUKA
# 1  A0A7S4AZV5  unreviewed  A0A7S4AZV5_CHRCT
# 2  A0A0P5BC06  unreviewed  A0A0P5BC06_9CRUS
# 3  A0A164K3P3  unreviewed  A0A164K3P3_9CRUS
# 4  A0A0N8BXH8  unreviewed  A0A0N8BXH8_9CRUS
# 5  A0A0P5XN56  unreviewed  A0A0P5XN56_9CRUS
# 6  A0A0P6EPE8  unreviewed  A0A0P6EPE8_9CRUS
# 7  A0A164X7T0  unreviewed  A0A164X7T0_9CRUS
#
#                                        Protein names           Gene Names  \
# 0  G-protein coupled receptors family 2 profile 2...   PANT1444_LOCUS5962
# 1  Frizzled/Smoothened 7TM domain-containing protein  PCAR00345_LOCUS1126
# 2                                 Protein smoothened                  NaN
# 3                                 Protein smoothened         APZ42_034340
# 4  Frizzled-2 (Wnt-receptor frizzled variant 1-li...         APZ42_020404
# 5                                         Frizzled-2                  NaN
# 6                                         Frizzled-2                  NaN
# 7                                         Frizzled-1         APZ42_020570
#
#                                             Organism  Length  AlphaFoldDB  \
# 0                             Phaeocystis antarctica     378  A0A7S0HIM9;
# 1  Chrysotila carterae (Marine alga) (Syracosphae...     205  A0A7S4AZV5;
# 2                                      Daphnia magna    1099  A0A0P5BC06;
# 3                                      Daphnia magna    1054  A0A164K3P3;
# 4                                      Daphnia magna     636  A0A0N8BXH8;
# 5                                      Daphnia magna     460  A0A0P5XN56;
# 6                                      Daphnia magna     557  A0A0P6EPE8;
# 7                                      Daphnia magna     713  A0A164X7T0;
#
#                                    Taxonomic lineage  Organism (ID)  \
# 0  Haptista (clade), Haptophyta (phylum), Prymnes...          33657
# 1  Haptista (clade), Haptophyta (phylum), Prymnes...          13221
# 2  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 3  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 4  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 5  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 6  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 7  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
#
#          Gene    Org
# 0  A0A7S0HIM9  9EUKA
# 1  A0A7S4AZV5  CHRCT
# 2  A0A0P5BC06  9CRUS
# 3  A0A164K3P3  9CRUS
# 4  A0A0N8BXH8  9CRUS
# 5  A0A0P5XN56  9CRUS
# 6  A0A0P6EPE8  9CRUS
# 7  A0A164X7T0  9CRUS
# At least one species specific to include!
# Summarizes: PF01534
# PF02076-2759
# DataFrame is empty for  Sphaeroforma arctica !
# DataFrame is empty for  Abeoforma whisleri !
# DataFrame is empty for  Pirum gemmata !
# DataFrame is empty for  Corallochytrium limacisporum !
# DataFrame is empty for  Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri) !
# DataFrame is empty for  Chrysochromulina tobinii !
# DataFrame is empty for  Phaeocystis antarctica !
# DataFrame is empty for  Calcidiscus leptoporus !
# DataFrame is empty for  Coccolithus braarudii !
# DataFrame is empty for  Haptolina brevifila !
# DataFrame is empty for  Haptolina ericina !
# DataFrame is empty for  Emiliania huxleyi (Coccolithophore) (Pontosphaera huxleyi) !
# DataFrame is empty for  Chrysotila carterae (Marine alga) (Syracosphaera carterae) !
# DataFrame is empty for  Prymnesium polylepis !
# DataFrame is empty for  Palpitomonas bilix !
# DataFrame is empty for  Daphnia magna !
# DataFrame is empty for  Podila verticillata NRRL 6337 !
# DataFrame is empty for  Nematocida parisii !
# DataFrame is empty for  Gracilariopsis chorda !
# DataFrame is empty for  Compsopogon caeruleus !
# DataFrame is empty for  Rhodosorus marinus !
# DataFrame is empty for  Timspurckia oligopyrenoides !
# DataFrame is empty for  Erythrolobus australicus !
# Empty DataFrame
# Columns: [Entry, Reviewed, Entry Name, Protein names, Gene Names, Organism, Length, AlphaFoldDB, Taxonomic lineage, Organism (ID), Gene, Org]
# Index: []
# No species specific to include!
# Summarizes: PF02076
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['Scientific_Name'] = selected_data['Organism'].apply(lambda x: ' '.join(x.split()[:2]))
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# /tmp/ipykernel_5034/3426324811.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['gpcr'] = gpcr
# /tmp/ipykernel_5034/3426324811.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['taxa'] = taxa
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# PF02101-2759
# DataFrame is empty for  Sphaeroforma arctica !
# DataFrame is empty for  Abeoforma whisleri !
# DataFrame is empty for  Pirum gemmata !
# DataFrame is empty for  Corallochytrium limacisporum !
# DataFrame is empty for  Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri) !
# DataFrame is empty for  Chrysochromulina tobinii !
# DataFrame is empty for  Phaeocystis antarctica !
# DataFrame is empty for  Calcidiscus leptoporus !
# DataFrame is empty for  Coccolithus braarudii !
# DataFrame is empty for  Haptolina brevifila !
# DataFrame is empty for  Haptolina ericina !
# DataFrame is empty for  Emiliania huxleyi (Coccolithophore) (Pontosphaera huxleyi) !
# DataFrame is empty for  Chrysotila carterae (Marine alga) (Syracosphaera carterae) !
# DataFrame is empty for  Prymnesium polylepis !
# DataFrame is empty for  Palpitomonas bilix !
# Entries found for  Daphnia magna !
# DataFrame is empty for  Podila verticillata NRRL 6337 !
# DataFrame is empty for  Nematocida parisii !
# DataFrame is empty for  Gracilariopsis chorda !
# DataFrame is empty for  Compsopogon caeruleus !
# DataFrame is empty for  Rhodosorus marinus !
# DataFrame is empty for  Timspurckia oligopyrenoides !
# DataFrame is empty for  Erythrolobus australicus !
#         Entry    Reviewed        Entry Name  \
# 0  A0A164N8Q0  unreviewed  A0A164N8Q0_9CRUS
# 1  A0A0P5T0J3  unreviewed  A0A0P5T0J3_9CRUS
#
#                                        Protein names    Gene Names  \
# 0  Class B secretin G-protein-coupled receptor gp...  APZ42_030973
# 1                         G-protein coupled receptor           NaN
#
#         Organism  Length  AlphaFoldDB  \
# 0  Daphnia magna     159  A0A164N8Q0;
# 1  Daphnia magna     332  A0A0P5T0J3;
#
#                                    Taxonomic lineage  Organism (ID)  \
# 0  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 1  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
#
#          Gene    Org
# 0  A0A164N8Q0  9CRUS
# 1  A0A0P5T0J3  9CRUS
# At least one species specific to include!
# Summarizes: PF02101
# PF02116-2759
# DataFrame is empty for  Sphaeroforma arctica !
# DataFrame is empty for  Abeoforma whisleri !
# DataFrame is empty for  Pirum gemmata !
# DataFrame is empty for  Corallochytrium limacisporum !
# DataFrame is empty for  Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri) !
# DataFrame is empty for  Chrysochromulina tobinii !
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['Scientific_Name'] = selected_data['Organism'].apply(lambda x: ' '.join(x.split()[:2]))
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# /tmp/ipykernel_5034/3426324811.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['gpcr'] = gpcr
# /tmp/ipykernel_5034/3426324811.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['taxa'] = taxa
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['Scientific_Name'] = selected_data['Organism'].apply(lambda x: ' '.join(x.split()[:2]))
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# /tmp/ipykernel_5034/3426324811.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['gpcr'] = gpcr
# /tmp/ipykernel_5034/3426324811.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['taxa'] = taxa
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['Scientific_Name'] = selected_data['Organism'].apply(lambda x: ' '.join(x.split()[:2]))
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# DataFrame is empty for  Phaeocystis antarctica !
# DataFrame is empty for  Calcidiscus leptoporus !
# DataFrame is empty for  Coccolithus braarudii !
# ...
# 14  Daphnia magna     342  A0A164WBL4;
# 15  Daphnia magna     505  A0A164Z745;
#
#                                     Taxonomic lineage  Organism (ID)  \
# 0   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 1   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 2   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 3   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 4   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 5   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 6   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 7   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 8   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 9   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 10  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 11  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 12  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 13  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 14  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 15  Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
#
#           Gene    Org
# 0   A0A4Y7MKR1  9CRUS
# 1   A0A4Y7MIL2  9CRUS
# 2   A0A4Y7MJU3  9CRUS
# 3   A0A4Y7MKB5  9CRUS
# 4   A0A4Y7MQ02  9CRUS
# 5   A0A4Y7MSY6  9CRUS
# 6   A0A0P4Z2N1  9CRUS
# 7   A0A0P5BWX8  9CRUS
# 8   A0A0P5PYA6  9CRUS
# 9   A0A0P5RKM5  9CRUS
# 10  A0A0P6GPB8  9CRUS
# 11  A0A164NKG6  9CRUS
# 12  A0A164RXI9  9CRUS
# 13  A0A164W825  9CRUS
# 14  A0A164WBL4  9CRUS
# 15  A0A164Z745  9CRUS
# At least one species specific to include!
# /tmp/ipykernel_5034/2592652550.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['Scientific_Name'] = selected_data['Organism'].apply(lambda x: ' '.join(x.split()[:2]))
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# /tmp/ipykernel_5034/3426324811.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['gpcr'] = gpcr
# /tmp/ipykernel_5034/3426324811.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['taxa'] = taxa
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# Summarizes: PF13965
# PF15100-2759
# DataFrame is empty for  Sphaeroforma arctica !
# DataFrame is empty for  Abeoforma whisleri !
# DataFrame is empty for  Pirum gemmata !
# DataFrame is empty for  Corallochytrium limacisporum !
# DataFrame is empty for  Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri) !
# DataFrame is empty for  Chrysochromulina tobinii !
# DataFrame is empty for  Phaeocystis antarctica !
# DataFrame is empty for  Calcidiscus leptoporus !
# DataFrame is empty for  Coccolithus braarudii !
# DataFrame is empty for  Haptolina brevifila !
# DataFrame is empty for  Haptolina ericina !
# DataFrame is empty for  Emiliania huxleyi (Coccolithophore) (Pontosphaera huxleyi) !
# DataFrame is empty for  Chrysotila carterae (Marine alga) (Syracosphaera carterae) !
# DataFrame is empty for  Prymnesium polylepis !
# DataFrame is empty for  Palpitomonas bilix !
# DataFrame is empty for  Daphnia magna !
# DataFrame is empty for  Podila verticillata NRRL 6337 !
# DataFrame is empty for  Nematocida parisii !
# DataFrame is empty for  Gracilariopsis chorda !
# DataFrame is empty for  Compsopogon caeruleus !
# DataFrame is empty for  Rhodosorus marinus !
# DataFrame is empty for  Timspurckia oligopyrenoides !
# DataFrame is empty for  Erythrolobus australicus !
# Empty DataFrame
# Columns: [Entry, Reviewed, Entry Name, Protein names, Gene Names, Organism, Length, AlphaFoldDB, Taxonomic lineage, Organism (ID), Gene, Org]
# Index: []
# No species specific to include!
# Summarizes: PF15100
# PF12430-2759
# DataFrame is empty for  Sphaeroforma arctica !
# DataFrame is empty for  Abeoforma whisleri !
# DataFrame is empty for  Pirum gemmata !
# DataFrame is empty for  Corallochytrium limacisporum !
# DataFrame is empty for  Diacronema lutheri (Unicellular marine alga) (Monochrysis lutheri) !
# Entries found for  Chrysochromulina tobinii !
# DataFrame is empty for  Phaeocystis antarctica !
# Entries found for  Calcidiscus leptoporus !
# DataFrame is empty for  Coccolithus braarudii !
# DataFrame is empty for  Haptolina brevifila !
# DataFrame is empty for  Haptolina ericina !
# Entries found for  Emiliania huxleyi (Coccolithophore) (Pontosphaera huxleyi) !
# DataFrame is empty for  Chrysotila carterae (Marine alga) (Syracosphaera carterae) !
# DataFrame is empty for  Prymnesium polylepis !
# Entries found for  Palpitomonas bilix !
# Entries found for  Daphnia magna !
# DataFrame is empty for  Podila verticillata NRRL 6337 !
# DataFrame is empty for  Nematocida parisii !
# Entries found for  Gracilariopsis chorda !
# DataFrame is empty for  Compsopogon caeruleus !
# Entries found for  Rhodosorus marinus !
# DataFrame is empty for  Timspurckia oligopyrenoides !
# DataFrame is empty for  Erythrolobus australicus !
#          Entry    Reviewed        Entry Name  \
# 0   A0A0M0JHE5  unreviewed  A0A0M0JHE5_9EUKA
# 1   A0A7S0J665  unreviewed  A0A7S0J665_9EUKA
# 2   A0A7S3SA89  unreviewed  A0A7S3SA89_EMIHU
# 3   A0A7S3GIX3  unreviewed  A0A7S3GIX3_9EUKA
# 4   A0A0P5FTA0  unreviewed  A0A0P5FTA0_9CRUS
# 5   A0A4Y7MIX0  unreviewed  A0A4Y7MIX0_9CRUS
# 6   A0A4Y7MIX1  unreviewed  A0A4Y7MIX1_9CRUS
# 7   A0A4Y7MLL8  unreviewed  A0A4Y7MLL8_9CRUS
# 8   A0A2V3IW80  unreviewed  A0A2V3IW80_9FLOR
# 9   A0A7S3A9R7  unreviewed  A0A7S3A9R7_9RHOD
# 10  A0A7S3EQE5  unreviewed  A0A7S3EQE5_9RHOD
#
#                                         Protein names  \
# 0                                  Golgi ph regulator
# 1   Abscisic acid G-protein coupled receptor-like ...
# 2   Abscisic acid G-protein coupled receptor-like ...
# 3   Abscisic acid G-protein coupled receptor-like ...
# 4                    EOG090X06XN (Golgi pH regulator)
# 5                                         EOG090X06XN
# 6                                         EOG090X06XN
# 7                                         EOG090X06XN
# 8                                  Golgi pH regulator
# 9   Abscisic acid G-protein coupled receptor-like ...
# 10  Abscisic acid G-protein coupled receptor-like ...
#
#                                    Gene Names  \
# 0                                 Ctob_003313
# 1                         CLEP1334_LOCUS17514
# 2                        EHUX00137_LOCUS17088
# 3                        PBIL07802_LOCUS30048
# 4                    EOG090X06XN APZ42_020748
# 5                                 EOG090X06XN
# 6                                 EOG090X06XN
# 7                                 EOG090X06XN
# 8                                 BWQ96_03897
# 9   RMAR00112_LOCUS34242 RMAR00112_LOCUS34245
# 10  RMAR00112_LOCUS34239 RMAR00112_LOCUS34244
#
#                                              Organism  Length  AlphaFoldDB  \
# 0                            Chrysochromulina tobinii     435  A0A0M0JHE5;
# 1                              Calcidiscus leptoporus     122  A0A7S0J665;
# 2   Emiliania huxleyi (Coccolithophore) (Pontospha...     298  A0A7S3SA89;
# 3                                  Palpitomonas bilix     307  A0A7S3GIX3;
# 4                                       Daphnia magna     466  A0A0P5FTA0;
# 5                                       Daphnia magna     466  A0A4Y7MIX0;
# 6                                       Daphnia magna     427  A0A4Y7MIX1;
# 7                                       Daphnia magna     395  A0A4Y7MLL8;
# 8                               Gracilariopsis chorda     484  A0A2V3IW80;
# 9                                  Rhodosorus marinus     491  A0A7S3A9R7;
# 10                                 Rhodosorus marinus     129  A0A7S3EQE5;
#
#                                     Taxonomic lineage  Organism (ID)  \
# 0   Haptista (clade), Haptophyta (phylum), Prymnes...        1460289
# 1   Haptista (clade), Haptophyta (phylum), Prymnes...         127549
# 2   Haptista (clade), Haptophyta (phylum), Prymnes...           2903
# 3   Eukaryota incertae sedis (no rank), Palpitomon...         652834
# 4   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 5   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 6   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 7   Opisthokonta (clade), Metazoa (kingdom), Eumet...          35525
# 8   Rhodophyta (phylum), Florideophyceae (class), ...         448386
# 9   Rhodophyta (phylum), Stylonematophyceae (class...         101924
# 10  Rhodophyta (phylum), Stylonematophyceae (class...         101924
#
#           Gene    Org
# 0   A0A0M0JHE5  9EUKA
# 1   A0A7S0J665  9EUKA
# 2   A0A7S3SA89  EMIHU
# 3   A0A7S3GIX3  9EUKA
# 4   A0A0P5FTA0  9CRUS
# 5   A0A4Y7MIX0  9CRUS
# 6   A0A4Y7MIX1  9CRUS
# 7   A0A4Y7MLL8  9CRUS
# 8   A0A2V3IW80  9FLOR
# 9   A0A7S3A9R7  9RHOD
# 10  A0A7S3EQE5  9RHOD
# At least one species specific to include!
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['Scientific_Name'] = selected_data['Organism'].apply(lambda x: ' '.join(x.split()[:2]))
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# /tmp/ipykernel_5034/3426324811.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['gpcr'] = gpcr
# /tmp/ipykernel_5034/3426324811.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_tree['taxa'] = taxa
# /tmp/ipykernel_5034/2496942008.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database['Taxonomic lineage'] = database['Taxonomic lineage'].apply(lambda x: str(x).replace("cellular organisms (no rank), Eukaryota (superkingdom), ",""))
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpcr[['Gene', 'Org']] = gpcr['Entry Name'].str.split('_', n=2, expand=True)
# /tmp/ipykernel_5034/2592652550.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_list['gpcr'] = name
# Summarizes: PF12430

# %%
pfam = pd.read_csv('../../datasets/full/uniprot-PF10323-35493.tsv', sep='\t')

# %%
pfam[['Gene', 'Org']] = pfam['Entry Name'].str.split('_', n=2, expand=True)

# %%
pfam
# Out:
#         Entry    Reviewed        Entry Name  \
# 0  A0AAE0DSG8  unreviewed  A0AAE0DSG8_9ROSI
#
#                                        Protein names   Gene Names  \
# 0  non-specific serine/threonine protein kinase (...  Dsin_031565
#
#               Organism  Length  AlphaFoldDB  \
# 0  Dipteronia sinensis     427          NaN
#
#                                    Taxonomic lineage  Organism (ID)  \
# 0  cellular organisms (no rank), Eukaryota (super...          43782
#
#          Gene    Org
# 0  A0AAE0DSG8  9ROSI
